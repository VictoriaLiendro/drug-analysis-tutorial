# %% [markdown]
# # **Bioinformatics Project - Computational Drug Discovery [Part 1] Download Bioactivity Data (Concised version)**
#
# Chanin Nantasenamat
#
# [*'Data Professor' YouTube channel*](http://youtube.com/dataprofessor)
#
# In this Jupyter notebook, we will be building a real-life **data science project** that you can include in your **data science portfolio**. Particularly, we will be building a machine learning model using the ChEMBL bioactivity data.
#
# In **Part 1**, we will be performing Data Collection and Pre-Processing from the ChEMBL Database.
#
# Note for this Concised Version:
# * Redundant code cells were deleted.
# * Code cells for saving files to Google Drive has been deleted.
#
# ---

# %% [markdown]
# ## **ChEMBL Database**
#
# The [*ChEMBL Database*](https://www.ebi.ac.uk/chembl/) is a database that contains curated bioactivity data of more than 2 million compounds. It is compiled from more than 76,000 documents, 1.2 million assays and the data spans 13,000 targets and 1,800 cells and 33,000 indications.
# [Data as of March 25, 2020; ChEMBL version 26].

# %% [markdown]
# ## **Installing libraries**

# %% [markdown]
# Install the ChEMBL web service package so that we can retrieve bioactivity data from the ChEMBL Database.

# %%
! pip install chembl_webresource_client
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.2/55.2 kB 4.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.4/61.4 kB 4.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 kB 5.9 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## **Importing libraries**

# %%
# Import necessary libraries
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# ## **Search for Target protein**

# %% [markdown]
# ### **Target search for Acetylcholinesterase**

# %%
# Target search for ErbB1
target = new_client.target
target_query = target.search('ErbB1')
#target_query = target.search('coronavirus')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#   cross_references      organism  \
# 0               []  Homo sapiens
# 1               []  Homo sapiens
# 2               []  Homo sapiens
# 3               []  Homo sapiens
# 4               []  Homo sapiens
# 5               []  Mus musculus
# 6               []  Homo sapiens
# 7               []  Homo sapiens
# 8               []  Homo sapiens
# 9               []  Homo sapiens
#
#                                            pref_name  score  \
# 0             Epidermal growth factor receptor erbB1   15.0
# 1  Protein cereblon/Epidermal growth factor receptor   14.0
# 2  MER intracellular domain/EGFR extracellular do...   13.0
# 3                                        EGFR/PPP1CA   13.0
# 4                                           VHL/EGFR   13.0
# 5             Epidermal growth factor receptor erbB1   12.0
# 6  Epidermal growth factor receptor and ErbB2 (HE...   11.0
# 7  Baculoviral IAP repeat-containing protein 2/Ep...   10.0
# ...

# %% [markdown]
# ### **Select and retrieve bioactivity data for *Epidermal growth factor receptor erbB1* (first entry)**

# %% [markdown]
# We will assign the fifth entry to the ***selected_target*** variable

# %%
selected_target = targets.target_chembl_id[5]
selected_target
# Out:
# 'CHEMBL3608'

# %% [markdown]
# Here, we will retrieve only bioactivity data for *Epidermal growth factor receptor erbB1* (CHEMBL203) that are reported as pChEMBL values. We want to use only one type of standard_type because we want our dataset to have uniformity in bioactivity in our dataset.

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(res)

# %%
df
# Out:
#                                           action_type activity_comment  \
# 0                                                None             None
# 1                                                None             None
# 2                                                None             None
# 3                                                None             None
# 4                                                None             None
# ..                                                ...              ...
# 81  {'action_type': 'BINDING AGENT', 'description'...             None
# 82                                               None             None
# 83  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 84                                               None             None
# 85  {'action_type': 'INHIBITOR', 'description': 'N...             None
#
#     activity_id                                activity_properties  \
# ...

# %% [markdown]
# Finally we will save the resulting bioactivity data to a CSV file **bioactivity_data.csv**.

# %%
df.to_csv('erbB1_bioactivity_data_raw.csv', index=False)

# %% [markdown]
# Copy files to Google Drive

# %%
from google.colab import drive
drive.mount('/content/gdrive/', force_remount=True)
# Out:
# Mounted at /content/gdrive/

# %% [markdown]
# Create *data* folder

# %%
! mkdir "/content/gdrive/My Drive/data/"

# %%
! cp bioactivity_data.csv "/content/gdrive/My Drive/data/"
# Out:
# cp: cannot stat 'bioactivity_data.csv': No such file or directory

# %%
! ls "/content/gdrive/My Drive/data"

# %%
! ls
# Out:
# erbB1_bioactivity_data_raw.csv	gdrive	sample_data

# %% [markdown]
# ## **Handling missing data**
# If any compounds has missing value for the **standard_value** and **canonical_smiles** column then drop it.

# %%
df2 = df[df.standard_value.notna()]
df2 = df2[df.canonical_smiles.notna()]
df2
# Out:
# <ipython-input-36-955aac5800f0>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df2 = df2[df.canonical_smiles.notna()]
#                                           action_type activity_comment  \
# 0                                                None             None
# 1                                                None             None
# 2                                                None             None
# 3                                                None             None
# 4                                                None             None
# ..                                                ...              ...
# 81  {'action_type': 'BINDING AGENT', 'description'...             None
# 82                                               None             None
# 83  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 84                                               None             None
# ...

# %%
len(df2.canonical_smiles.unique())
# Out:
# 81

# %%
df2_nr = df2.drop_duplicates(['canonical_smiles'])
df2_nr
# Out:
#                                           action_type activity_comment  \
# 0                                                None             None
# 1                                                None             None
# 2                                                None             None
# 3                                                None             None
# 4                                                None             None
# ..                                                ...              ...
# 80  {'action_type': 'BINDING AGENT', 'description'...             None
# 81  {'action_type': 'BINDING AGENT', 'description'...             None
# 82                                               None             None
# 83  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 84                                               None             None
#
#     activity_id                                activity_properties  \
# ...

# %% [markdown]
# ## **Data pre-processing of the bioactivity data**

# %% [markdown]
# ### **Combine the 3 columns (molecule_chembl_id,canonical_smiles,standard_value) and bioactivity_class into a DataFrame**

# %%
selection = ['molecule_chembl_id','canonical_smiles','standard_value']
df3 = df2_nr[selection]
df3
# Out:
#    molecule_chembl_id                                   canonical_smiles  \
# 0        CHEMBL292323  COc1cccc2c(C(=O)Nc3ccccc3)c(SSc3c(C(=O)Nc4cccc...
# 1        CHEMBL304414  Cn1c(SSc2c(C(=O)Nc3ccccc3)c3ccccc3n2C)c(C(=O)N...
# 2         CHEMBL62176                 CN1C(=S)C(C(=O)Nc2ccccc2)c2ccccc21
# 3         CHEMBL62701  Cn1c(SSc2c(C(=O)Nc3ccccc3)c3cccnc3n2C)c(C(=O)N...
# 4        CHEMBL137617               C/N=N/Nc1ccc2ncnc(Nc3cccc(Br)c3)c2c1
# ..                ...                                                ...
# 80      CHEMBL5430172                          CN(C(=O)Nc1ccccn1)C1CCCC1
# 81      CHEMBL5411911                       CN(C(=O)N(C)C1CCCC1)c1ccccc1
# 82      CHEMBL5420832                       CN(C(=O)N(C)C1CCCC1)c1ccccn1
# 83      CHEMBL5424516  COc1cc2ncnc(NCc3ccc(NC(=O)C(c4ccccc4)N4Cc5cccc...
# 84      CHEMBL4284413            O=C(Nc1nccs1)C(c1ccccc1)N1Cc2ccccc2C1=O
#
#    standard_value
# 0        100000.0
# 1        100000.0
# 2        100000.0
# ...

# %% [markdown]
# Saves dataframe to CSV file

# %%
df3.to_csv('erbB1_02_bioactivity_data_preprocessed.csv', index=False)

# %% [markdown]
# ### **Labeling compounds as either being active, inactive or intermediate**
# The bioactivity data is in the IC50 unit. Compounds having values of less than 1000 nM will be considered to be **active** while those greater than 10,000 nM will be considered to be **inactive**. As for those values in between 1,000 and 10,000 nM will be referred to as **intermediate**.

# %%
df4 = pd.read_csv('erbB1_02_bioactivity_data_preprocessed.csv')

# %%
bioactivity_threshold = []
for i in df4.standard_value:
  if float(i) >= 10000:
    bioactivity_threshold.append("inactive")
  elif float(i) <= 1000:
    bioactivity_threshold.append("active")
  else:
    bioactivity_threshold.append("intermediate")

# %%
bioactivity_class = pd.Series(bioactivity_threshold, name='class')
df5 = pd.concat([df4, bioactivity_class], axis=1)
df5
# Out:
#    molecule_chembl_id                                   canonical_smiles  \
# 0        CHEMBL292323  COc1cccc2c(C(=O)Nc3ccccc3)c(SSc3c(C(=O)Nc4cccc...
# 1        CHEMBL304414  Cn1c(SSc2c(C(=O)Nc3ccccc3)c3ccccc3n2C)c(C(=O)N...
# 2         CHEMBL62176                 CN1C(=S)C(C(=O)Nc2ccccc2)c2ccccc21
# 3         CHEMBL62701  Cn1c(SSc2c(C(=O)Nc3ccccc3)c3cccnc3n2C)c(C(=O)N...
# 4        CHEMBL137617               C/N=N/Nc1ccc2ncnc(Nc3cccc(Br)c3)c2c1
# ..                ...                                                ...
# 76      CHEMBL5430172                          CN(C(=O)Nc1ccccn1)C1CCCC1
# 77      CHEMBL5411911                       CN(C(=O)N(C)C1CCCC1)c1ccccc1
# 78      CHEMBL5420832                       CN(C(=O)N(C)C1CCCC1)c1ccccn1
# 79      CHEMBL5424516  COc1cc2ncnc(NCc3ccc(NC(=O)C(c4ccccc4)N4Cc5cccc...
# 80      CHEMBL4284413            O=C(Nc1nccs1)C(c1ccccc1)N1Cc2ccccc2C1=O
#
#     standard_value         class
# 0        100000.00      inactive
# ...

# %% [markdown]
# Saves dataframe to CSV file

# %%
df5.to_csv('erbB1_03_bioactivity_data_curated.csv', index=False)

# %%
! zip erbB1.zip *.csv
# Out:
#   adding: acetylcholinesterase_02_bioactivity_data_preprocessed.csv (deflated 73%)
#   adding: erbB1_02_bioactivity_data_preprocessed.csv (deflated 73%)
#   adding: erbB1_03_bioactivity_data_curated.csv (deflated 75%)
#   adding: erbB1_bioactivity_data_raw.csv (deflated 88%)

# %%
! ls -l
# Out:
# total 96
# -rw-r--r-- 1 root root  5424 Dec 17 21:59 acetylcholinesterase_02_bioactivity_data_preprocessed.csv
# -rw-r--r-- 1 root root  5424 Dec 17 21:59 erbB1_02_bioactivity_data_preprocessed.csv
# -rw-r--r-- 1 root root  6153 Dec 17 22:03 erbB1_03_bioactivity_data_curated.csv
# -rw-r--r-- 1 root root 50117 Dec 17 21:54 erbB1_bioactivity_data_raw.csv
# -rw-r--r-- 1 root root 11117 Dec 17 22:03 erbB1.zip
# drwx------ 6 root root  4096 Dec 17 21:54 gdrive
# drwxr-xr-x 1 root root  4096 Dec 16 23:52 sample_data

# %% [markdown]
# ---
